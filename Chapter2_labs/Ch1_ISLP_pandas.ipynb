# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Auto.csv')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# @title mpg

from matplotlib import pyplot as plt
df['mpg'].plot(kind='hist', bins=20, title='mpg')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# We now take a look at the column of Auto corresponding to the variable horsepower:

# %%
df['horsepower']
# Out:
# 0      130
# 1      165
# 2      150
# 3      150
# 4      140
#       ...
# 392     86
# 393     52
# 394     84
# 395     79
# 396     82
# Name: horsepower, Length: 397, dtype: object

# %%
np.unique(df['horsepower'])
# Out:
# array(['100', '102', '103', '105', '107', '108', '110', '112', '113',
#        '115', '116', '120', '122', '125', '129', '130', '132', '133',
#        '135', '137', '138', '139', '140', '142', '145', '148', '149',
#        '150', '152', '153', '155', '158', '160', '165', '167', '170',
#        '175', '180', '190', '193', '198', '200', '208', '210', '215',
#        '220', '225', '230', '46', '48', '49', '52', '53', '54', '58',
#        '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70',
#        '71', '72', '74', '75', '76', '77', '78', '79', '80', '81', '82',
#        '83', '84', '85', '86', '87', '88', '89', '90', '91', '92', '93',
#        '94', '95', '96', '97', '98', '?'], dtype=object)

# %% [markdown]
# We see we have ? as our culprit making the dtype an object. So we try to replace it.

# %%
df = pd.read_csv('Auto.csv',na_values=['?'])
df['horsepower'].sum()
# Out:
# 40952.0

# %% [markdown]
# this replaces the occurances of ? with np.nan(Not a number)

# %%
df.isna?

# %% [markdown]
# This checks for the missing values

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      5
# weight          0
# acceleration    0
# year            0
# origin          0
# name            0
# dtype: int64

# %%
ls = pd.isnull(df['horsepower'])
df[ls]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 32   25.0          4          98.0         NaN    2046          19.0    71
# 126  21.0          6         200.0         NaN    2875          17.0    74
# 330  40.9          4          85.0         NaN    1835          17.3    80
# 336  23.6          4         140.0         NaN    2905          14.3    80
# 354  34.5          4         100.0         NaN    2320          15.8    81
#
#      origin                  name
# 32        1            ford pinto
# 126       1         ford maverick
# 330       2  renault lecar deluxe
# 336       1    ford mustang cobra
# 354       2           renault 18i

# %%
df.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
df[:3]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite

# %%
idx_80 = df['year'] > 80
df[idx_80]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 338  27.2          4         135.0        84.0    2490          15.7    81
# 339  26.6          4         151.0        84.0    2635          16.4    81
# 340  25.8          4         156.0        92.0    2620          14.4    81
# 341  23.5          6         173.0       110.0    2725          12.6    81
# 342  30.0          4         135.0        84.0    2385          12.9    81
# 343  39.1          4          79.0        58.0    1755          16.9    81
# 344  39.0          4          86.0        64.0    1875          16.4    81
# 345  35.1          4          81.0        60.0    1760          16.1    81
# 346  32.3          4          97.0        67.0    2065          17.8    81
# 347  37.0          4          85.0        65.0    1975          19.4    81
# 348  37.7          4          89.0        62.0    2050          17.3    81
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=397, step=1)

# %% [markdown]
# We can use the set_index() method to re-name the rows using the contents of df['name'].

# %%
Auto_re = df.set_index('name')
Auto_re
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
# ...

# %%
Auto_re.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin'],
#       dtype='object')

# %% [markdown]
# Now that the index has been set to name, we can access rows of the data frame by name using the {loc[]} method
#
# loc = Access a group of rows and columns by label(s) or a boolean array.

# %%
rows = ['amc rebel sst', 'ford torino']
Auto_re.loc[rows]
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# name
# amc rebel sst  16.0          8         304.0       150.0    3433
# ford torino    17.0          8         302.0       140.0    3449
#
#                acceleration  year  origin
# name
# amc rebel sst          12.0    70       1
# ford torino            10.5    70       1

# %%
Auto_re.loc['ford torino']
# Out:
# mpg               17.0
# cylinders          8.0
# displacement     302.0
# horsepower       140.0
# weight          3449.0
# acceleration      10.5
# year              70.0
# origin             1.0
# Name: ford torino, dtype: float64

# %%
Auto_re.loc['ford torino','mpg']
# Out:
# 17.0

# %% [markdown]
# As an alternative to using the index name, we could retrieve the 4th and 5th rows of Auto using the {iloc[]} method:

# %%
Auto_re.iloc[[3,4]]
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# name
# amc rebel sst  16.0          8         304.0       150.0    3433
# ford torino    17.0          8         302.0       140.0    3449
#
#                acceleration  year  origin
# name
# amc rebel sst          12.0    70       1
# ford torino            10.5    70       1

# %% [markdown]
# We can also use it to retrieve the 1st, 3rd and and 4th columns of Auto_re:

# %%
Auto_re.iloc[:,[0,2,3]]
# Out:
#                             mpg  displacement  horsepower
# name
# chevrolet chevelle malibu  18.0         307.0       130.0
# buick skylark 320          15.0         350.0       165.0
# plymouth satellite         18.0         318.0       150.0
# amc rebel sst              16.0         304.0       150.0
# ford torino                17.0         302.0       140.0
# ...                         ...           ...         ...
# ford mustang gl            27.0         140.0        86.0
# vw pickup                  44.0          97.0        52.0
# dodge rampage              32.0         135.0        84.0
# ford ranger                28.0         120.0        79.0
# chevy s-10                 31.0         119.0        82.0
#
# [397 rows x 3 columns]

# %% [markdown]
# Index entries need not be unique: there are several cars in the data frame named ford galaxie 500.

# %%
Auto_re.loc['ford galaxie 500']
# Out:
#                    mpg  cylinders  displacement  horsepower  weight  \
# name
# ford galaxie 500  15.0          8         429.0       198.0    4341
# ford galaxie 500  14.0          8         351.0       153.0    4154
# ford galaxie 500  14.0          8         351.0       153.0    4129
#
#                   acceleration  year  origin
# name
# ford galaxie 500          10.0    70       1
# ford galaxie 500          13.5    71       1
# ford galaxie 500          13.0    72       1

# %%
Auto_re.loc['ford galaxie 500',['mpg','weight']]
# Out:
#                    mpg  weight
# name
# ford galaxie 500  15.0    4341
# ford galaxie 500  14.0    4154
# ford galaxie 500  14.0    4129

# %% [markdown]
# Suppose now that we want to create a data frame consisting of the weight and origin of the subset of cars with year greater than 80 --- i.e. those built after 1980. To do this, we first create a Boolean array that indexes the rows. The loc[] method allows for Boolean entries as well as strings:

# %%
idx = Auto_re['year']>80
idx
# Out:
# name
# chevrolet chevelle malibu    False
# buick skylark 320            False
# plymouth satellite           False
# amc rebel sst                False
# ford torino                  False
#                              ...
# ford mustang gl               True
# vw pickup                     True
# dodge rampage                 True
# ford ranger                   True
# chevy s-10                    True
# Name: year, Length: 397, dtype: bool

# %%
Auto_re.loc[idx,['weight','origin']]
# Out:
#                                    weight  origin
# name
# plymouth reliant                     2490       1
# buick skylark                        2635       1
# dodge aries wagon (sw)               2620       1
# chevrolet citation                   2725       1
# plymouth reliant                     2385       1
# toyota starlet                       1755       3
# plymouth champ                       1875       1
# honda civic 1300                     1760       3
# subaru                               2065       3
# datsun 210 mpg                       1975       3
# toyota tercel                        2050       3
# mazda glc 4                          1985       3
# plymouth horizon 4                   2215       1
# ford escort 4w                       2045       1
# ford escort 2h                       2380       1
# volkswagen jetta                     2190       2
# renault 18i                          2320       2
# honda prelude                        2210       3
# ...

# %% [markdown]
# To do this in concise manner we can use Lambda func in python:

# %%
Auto_re.loc[lambda df: df['year'] > 80, ['weight', 'origin']]
# Out:
#                                    weight  origin
# name
# plymouth reliant                     2490       1
# buick skylark                        2635       1
# dodge aries wagon (sw)               2620       1
# chevrolet citation                   2725       1
# plymouth reliant                     2385       1
# toyota starlet                       1755       3
# plymouth champ                       1875       1
# honda civic 1300                     1760       3
# subaru                               2065       3
# datsun 210 mpg                       1975       3
# toyota tercel                        2050       3
# mazda glc 4                          1985       3
# plymouth horizon 4                   2215       1
# ford escort 4w                       2045       1
# ford escort 2h                       2380       1
# volkswagen jetta                     2190       2
# renault 18i                          2320       2
# honda prelude                        2210       3
# ...

# %% [markdown]
# The `lambda` call creates a function that takes a single argument, here df, and returns `df['year']>80`. Since it is created inside the `loc[]` method for the dataframe Auto_re, that dataframe will be the argument supplied. As another example of using a lambda, suppose that we want all cars built after 1980 that achieve greater than `30 miles per gallon`:

# %%
Auto_re.loc[lambda df: (df['year']>80) & (df['mpg']>30),['weight']]
# Out:
#                                    weight
# name
# toyota starlet                       1755
# plymouth champ                       1875
# honda civic 1300                     1760
# subaru                               2065
# datsun 210 mpg                       1975
# toyota tercel                        2050
# mazda glc 4                          1985
# plymouth horizon 4                   2215
# ford escort 4w                       2045
# volkswagen jetta                     2190
# renault 18i                          2320
# honda prelude                        2210
# toyota corolla                       2350
# datsun 200sx                         2615
# mazda 626                            2635
# volvo diesel                         3160
# chevrolet cavalier 2-door            2395
# pontiac j2000 se hatchback           2575
# volkswagen rabbit l                  1980
# mazda glc custom l                   2025
# mazda glc custom                     1970
# ...

# %% [markdown]
# The symbol `&` computes an element-wise and operation. As another example, suppose that we want to retrieve all `Ford` and `Datsun` cars with displacement less than `300`. We check whether each name entry contains either the string ford or datsun using the `str.contains()` method of the index attribute of of the dataframe:

# %%
Auto_re.loc[lambda df: (df['displacement']<300) & (df.index.str.contains('ford') | df.index.str.contains('datsun')),['weight']]
# Out:
#                        weight
# name
# ford maverick            2587
# datsun pl510             2130
# datsun pl510             2130
# ford pinto               2046
# ford torino 500          3302
# ford mustang             3139
# datsun 1200              1613
# ford pinto runabout      2226
# ford pinto (sw)          2395
# datsun 510 (sw)          2288
# ford maverick            3021
# datsun 610               2379
# ford pinto               2310
# ford maverick            2875
# datsun b210              1950
# ford pinto               2451
# datsun 710               2003
# ford maverick            3158
# ford pinto               2639
# datsun 710               2545
# ford pinto               2984
# ford maverick            3012
# ford granada ghia        3574
# datsun b-210             1990
# ford pinto               2565
# datsun f-10 hatchback    1945
# ford granada             3525
# ford mustang ii 2+2      2755
# datsun 810               2815
# ford fiesta              1800
# ...

# %% [markdown]
# In summary, a powerful set of operations is available to index the rows and columns of data frames. For integer based queries, use the `iloc[]` method. For string and Boolean selections, use the `loc[]` method. For functional queries that filter rows, use the `loc[]` method with a function (typically a `lambda`) in the rows argument.
